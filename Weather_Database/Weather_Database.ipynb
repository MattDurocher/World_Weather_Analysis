# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
#Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
# Import the requests library.
import requests

# Import the API key.
from config_2 import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cherskiy
# Processing Record 2 of Set 1 | babanusah
# City not found. Skipping...
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | klaksvik
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | saint-philippe
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | zwedru
# Processing Record 10 of Set 1 | preobrazheniye
# Processing Record 11 of Set 1 | talakan
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | chuy
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | lebu
# Processing Record 17 of Set 1 | ponta do sol
# Processing Record 18 of Set 1 | thompson
# Processing Record 19 of Set 1 | zelenogorskiy
# Processing Record 20 of Set 1 | bambous virieux
# Processing Record 21 of Set 1 | monte alegre
# Processing Record 22 of Set 1 | iqaluit
# Processing Record 23 of Set 1 | carnarvon
# Processing Record 24 of Set 1 | sao joao da barra
# Processing Record 25 of Set 1 | yambio
# Processing Record 26 of Set 1 | umm lajj
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | ada
# Processing Record 29 of Set 1 | port hardy
# Processing Record 30 of Set 1 | bandar-e lengeh
# Processing Record 31 of Set 1 | nome
# Processing Record 32 of Set 1 | kaitangata
# Processing Record 33 of Set 1 | dinanagar
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | kavieng
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | kruisfontein
# Processing Record 39 of Set 1 | provideniya
# Processing Record 40 of Set 1 | jipijapa
# Processing Record 41 of Set 1 | arraial do cabo
# Processing Record 42 of Set 1 | chokurdakh
# Processing Record 43 of Set 1 | atuona
# Processing Record 44 of Set 1 | lagoa
# Processing Record 45 of Set 1 | qaanaaq
# Processing Record 46 of Set 1 | gari
# Processing Record 47 of Set 1 | praya
# Processing Record 48 of Set 1 | bayan
# Processing Record 49 of Set 1 | bintulu
# Processing Record 50 of Set 1 | hilo
# Processing Record 1 of Set 2 | olinda
# Processing Record 2 of Set 2 | havoysund
# Processing Record 3 of Set 2 | kushima
# Processing Record 4 of Set 2 | rikitea
# Processing Record 5 of Set 2 | ternate
# Processing Record 6 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | tsiroanomandidy
# Processing Record 10 of Set 2 | laguna
# Processing Record 11 of Set 2 | taltal
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | warri
# Processing Record 14 of Set 2 | rovaniemi
# Processing Record 15 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 2 | bluff
# Processing Record 17 of Set 2 | deputatskiy
# Processing Record 18 of Set 2 | tura
# Processing Record 19 of Set 2 | kavaratti
# Processing Record 20 of Set 2 | maceio
# Processing Record 21 of Set 2 | najran
# Processing Record 22 of Set 2 | vestmanna
# Processing Record 23 of Set 2 | mar del plata
# Processing Record 24 of Set 2 | esperance
# Processing Record 25 of Set 2 | galiwinku
# City not found. Skipping...
# Processing Record 26 of Set 2 | port macquarie
# Processing Record 27 of Set 2 | hofn
# Processing Record 28 of Set 2 | kamaishi
# Processing Record 29 of Set 2 | college
# Processing Record 30 of Set 2 | salinas
# Processing Record 31 of Set 2 | waingapu
# Processing Record 32 of Set 2 | comodoro rivadavia
# Processing Record 33 of Set 2 | rudnik
# Processing Record 34 of Set 2 | sorochinsk
# Processing Record 35 of Set 2 | san policarpo
# Processing Record 36 of Set 2 | hobart
# Processing Record 37 of Set 2 | torbay
# Processing Record 38 of Set 2 | busselton
# Processing Record 39 of Set 2 | augusto correa
# Processing Record 40 of Set 2 | kunya
# Processing Record 41 of Set 2 | georgetown
# Processing Record 42 of Set 2 | manga
# Processing Record 43 of Set 2 | arlit
# Processing Record 44 of Set 2 | takoradi
# Processing Record 45 of Set 2 | nantai
# Processing Record 46 of Set 2 | mangrol
# Processing Record 47 of Set 2 | butaritari
# Processing Record 48 of Set 2 | sarahan
# Processing Record 49 of Set 2 | vostok
# Processing Record 50 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 1 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 3 | kadykchan
# City not found. Skipping...
# Processing Record 3 of Set 3 | nizwa
# Processing Record 4 of Set 3 | saskylakh
# Processing Record 5 of Set 3 | the valley
# Processing Record 6 of Set 3 | brae
# Processing Record 7 of Set 3 | yellowknife
# Processing Record 8 of Set 3 | phulpur
# Processing Record 9 of Set 3 | boguchany
# Processing Record 10 of Set 3 | westport
# Processing Record 11 of Set 3 | beringovskiy
# Processing Record 12 of Set 3 | sungaipenuh
# Processing Record 13 of Set 3 | chateauroux
# Processing Record 14 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 15 of Set 3 | knysna
# Processing Record 16 of Set 3 | port said
# Processing Record 17 of Set 3 | cape town
# Processing Record 18 of Set 3 | goderich
# Processing Record 19 of Set 3 | saint-leu
# Processing Record 20 of Set 3 | aklavik
# Processing Record 21 of Set 3 | mayo
# Processing Record 22 of Set 3 | sitka
# Processing Record 23 of Set 3 | linqiong
# Processing Record 24 of Set 3 | ahipara
# Processing Record 25 of Set 3 | paka
# Processing Record 26 of Set 3 | shelburne
# Processing Record 27 of Set 3 | kisangani
# Processing Record 28 of Set 3 | tigre
# Processing Record 29 of Set 3 | savannah bight
# Processing Record 30 of Set 3 | santa cruz
# Processing Record 31 of Set 3 | kempsey
# Processing Record 32 of Set 3 | tuktoyaktuk
# Processing Record 33 of Set 3 | oistins
# Processing Record 34 of Set 3 | jamestown
# Processing Record 35 of Set 3 | port hawkesbury
# Processing Record 36 of Set 3 | richards bay
# Processing Record 37 of Set 3 | keuruu
# Processing Record 38 of Set 3 | cidreira
# Processing Record 39 of Set 3 | chaozhou
# Processing Record 40 of Set 3 | san cristobal
# Processing Record 41 of Set 3 | bonavista
# Processing Record 42 of Set 3 | moose factory
# Processing Record 43 of Set 3 | nikolskoye
# Processing Record 44 of Set 3 | kismayo
# Processing Record 45 of Set 3 | sisophon
# Processing Record 46 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 3 | pampa
# Processing Record 49 of Set 3 | elko
# Processing Record 50 of Set 3 | nanortalik
# Processing Record 1 of Set 4 | saint george
# Processing Record 2 of Set 4 | wajir
# Processing Record 3 of Set 4 | pandan
# Processing Record 4 of Set 4 | cedar city
# Processing Record 5 of Set 4 | batemans bay
# Processing Record 6 of Set 4 | santarem
# Processing Record 7 of Set 4 | cabra
# Processing Record 8 of Set 4 | vila velha
# Processing Record 9 of Set 4 | kuhestan
# City not found. Skipping...
# Processing Record 10 of Set 4 | coquimbo
# Processing Record 11 of Set 4 | norman wells
# Processing Record 12 of Set 4 | jalu
# Processing Record 13 of Set 4 | guerrero negro
# Processing Record 14 of Set 4 | sistranda
# Processing Record 15 of Set 4 | lipari
# Processing Record 16 of Set 4 | flin flon
# Processing Record 17 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 4 | tshikapa
# Processing Record 19 of Set 4 | alenquer
# Processing Record 20 of Set 4 | bethel
# Processing Record 21 of Set 4 | longavi
# Processing Record 22 of Set 4 | nalut
# Processing Record 23 of Set 4 | san patricio
# Processing Record 24 of Set 4 | vao
# Processing Record 25 of Set 4 | balaipungut
# Processing Record 26 of Set 4 | pevek
# Processing Record 27 of Set 4 | barrow
# Processing Record 28 of Set 4 | llanes
# Processing Record 29 of Set 4 | mangai
# Processing Record 30 of Set 4 | sao paulo de olivenca
# Processing Record 31 of Set 4 | bindi
# Processing Record 32 of Set 4 | itarema
# Processing Record 33 of Set 4 | benguela
# Processing Record 34 of Set 4 | harper
# Processing Record 35 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 4 | khiri mat
# Processing Record 37 of Set 4 | baillif
# Processing Record 38 of Set 4 | hualmay
# Processing Record 39 of Set 4 | laiyang
# Processing Record 40 of Set 4 | olafsvik
# Processing Record 41 of Set 4 | alegrete
# Processing Record 42 of Set 4 | maldonado
# Processing Record 43 of Set 4 | iskateley
# Processing Record 44 of Set 4 | souillac
# Processing Record 45 of Set 4 | oussouye
# Processing Record 46 of Set 4 | evensk
# Processing Record 47 of Set 4 | waipawa
# Processing Record 48 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 49 of Set 4 | katobu
# Processing Record 50 of Set 4 | leningradskiy
# Processing Record 1 of Set 5 | mitsamiouli
# Processing Record 2 of Set 5 | dudinka
# Processing Record 3 of Set 5 | oranjemund
# Processing Record 4 of Set 5 | natal
# Processing Record 5 of Set 5 | faya
# Processing Record 6 of Set 5 | victoria
# Processing Record 7 of Set 5 | ilulissat
# Processing Record 8 of Set 5 | praia da vitoria
# Processing Record 9 of Set 5 | huarmey
# Processing Record 10 of Set 5 | bell ville
# Processing Record 11 of Set 5 | karachi
# Processing Record 12 of Set 5 | vardo
# Processing Record 13 of Set 5 | lucapa
# Processing Record 14 of Set 5 | sabzevar
# Processing Record 15 of Set 5 | lalibela
# Processing Record 16 of Set 5 | praia
# Processing Record 17 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 5 | haines junction
# Processing Record 19 of Set 5 | guozhen
# Processing Record 20 of Set 5 | pajapan
# Processing Record 21 of Set 5 | waw
# Processing Record 22 of Set 5 | bengkulu
# Processing Record 23 of Set 5 | huari
# Processing Record 24 of Set 5 | kijang
# Processing Record 25 of Set 5 | mangrul pir
# Processing Record 26 of Set 5 | pisco
# Processing Record 27 of Set 5 | vestmannaeyjar
# Processing Record 28 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 5 | komsomolskiy
# Processing Record 30 of Set 5 | niksic
# Processing Record 31 of Set 5 | ajdabiya
# Processing Record 32 of Set 5 | avarua
# Processing Record 33 of Set 5 | bogalusa
# Processing Record 34 of Set 5 | awjilah
# Processing Record 35 of Set 5 | eskasem
# City not found. Skipping...
# Processing Record 36 of Set 5 | khorinsk
# Processing Record 37 of Set 5 | bambanglipuro
# Processing Record 38 of Set 5 | faanui
# Processing Record 39 of Set 5 | castro
# Processing Record 40 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 5 | coihaique
# Processing Record 42 of Set 5 | namibe
# Processing Record 43 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 44 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 5 | okha
# Processing Record 46 of Set 5 | mnogovershinnyy
# Processing Record 47 of Set 5 | norwich
# Processing Record 48 of Set 5 | solnechnyy
# Processing Record 49 of Set 5 | carikar
# City not found. Skipping...
# Processing Record 50 of Set 5 | lavrentiya
# Processing Record 1 of Set 6 | vrangel
# Processing Record 2 of Set 6 | villa constitucion
# Processing Record 3 of Set 6 | tsabong
# Processing Record 4 of Set 6 | kutum
# Processing Record 5 of Set 6 | barcelos
# Processing Record 6 of Set 6 | aksarka
# Processing Record 7 of Set 6 | tautira
# Processing Record 8 of Set 6 | mayskiy
# Processing Record 9 of Set 6 | amapa
# Processing Record 10 of Set 6 | leirvik
# Processing Record 11 of Set 6 | sukumo
# Processing Record 12 of Set 6 | cabo san lucas
# Processing Record 13 of Set 6 | sembakung
# Processing Record 14 of Set 6 | dhana
# Processing Record 15 of Set 6 | talnakh
# Processing Record 16 of Set 6 | fortuna
# Processing Record 17 of Set 6 | awbari
# Processing Record 18 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 6 | narsaq
# Processing Record 21 of Set 6 | pontianak
# Processing Record 22 of Set 6 | shirokiy
# Processing Record 23 of Set 6 | hegang
# Processing Record 24 of Set 6 | pacific grove
# Processing Record 25 of Set 6 | zaykovo
# Processing Record 26 of Set 6 | anuchino
# Processing Record 27 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 6 | sinnamary
# Processing Record 29 of Set 6 | shwebo
# Processing Record 30 of Set 6 | qingdao
# Processing Record 31 of Set 6 | seymchan
# Processing Record 32 of Set 6 | la ronge
# Processing Record 33 of Set 6 | ust-nera
# Processing Record 34 of Set 6 | ikwiriri
# Processing Record 35 of Set 6 | dien bien
# City not found. Skipping...
# Processing Record 36 of Set 6 | dasoguz
# Processing Record 37 of Set 6 | kahului
# Processing Record 38 of Set 6 | bredasdorp
# Processing Record 39 of Set 6 | koslan
# Processing Record 40 of Set 6 | garden city
# Processing Record 41 of Set 6 | mgandu
# Processing Record 42 of Set 6 | touros
# Processing Record 43 of Set 6 | khatanga
# Processing Record 44 of Set 6 | beloha
# Processing Record 45 of Set 6 | goma
# Processing Record 46 of Set 6 | zagreb
# Processing Record 47 of Set 6 | hami
# Processing Record 48 of Set 6 | songkhla
# Processing Record 49 of Set 6 | codrington
# Processing Record 50 of Set 6 | opuwo
# Processing Record 1 of Set 7 | naze
# Processing Record 2 of Set 7 | nichinan
# Processing Record 3 of Set 7 | luganville
# Processing Record 4 of Set 7 | upernavik
# Processing Record 5 of Set 7 | enumclaw
# Processing Record 6 of Set 7 | sisimiut
# Processing Record 7 of Set 7 | rincon
# Processing Record 8 of Set 7 | fort nelson
# Processing Record 9 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 7 | porto novo
# Processing Record 11 of Set 7 | shetpe
# Processing Record 12 of Set 7 | mount gambier
# Processing Record 13 of Set 7 | ambilobe
# Processing Record 14 of Set 7 | semnan
# Processing Record 15 of Set 7 | tasiilaq
# Processing Record 16 of Set 7 | skibbereen
# Processing Record 17 of Set 7 | turukhansk
# Processing Record 18 of Set 7 | along
# Processing Record 19 of Set 7 | ratnapura
# Processing Record 20 of Set 7 | sydney
# Processing Record 21 of Set 7 | maningrida
# Processing Record 22 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 7 | janow lubelski
# Processing Record 24 of Set 7 | chernyakhiv
# Processing Record 25 of Set 7 | ribeira grande
# Processing Record 26 of Set 7 | makrikapa
# City not found. Skipping...
# Processing Record 27 of Set 7 | seoul
# Processing Record 28 of Set 7 | kalmunai
# Processing Record 29 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 30 of Set 7 | longyearbyen
# Processing Record 31 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 32 of Set 7 | tilichiki
# Processing Record 33 of Set 7 | atar
# Processing Record 34 of Set 7 | adrasmon
# Processing Record 35 of Set 7 | lompoc
# Processing Record 36 of Set 7 | eenhana
# Processing Record 37 of Set 7 | chaa-khol
# City not found. Skipping...
# Processing Record 38 of Set 7 | yurimaguas
# Processing Record 39 of Set 7 | port maria
# Processing Record 40 of Set 7 | portland
# Processing Record 41 of Set 7 | hasaki
# Processing Record 42 of Set 7 | dikson
# Processing Record 43 of Set 7 | tigil
# Processing Record 44 of Set 7 | airai
# Processing Record 45 of Set 7 | novorzhev
# Processing Record 46 of Set 7 | kodiak
# Processing Record 47 of Set 7 | elizabethton
# Processing Record 48 of Set 7 | tala
# Processing Record 49 of Set 7 | wamba
# Processing Record 50 of Set 7 | inhambane
# Processing Record 1 of Set 8 | cayenne
# Processing Record 2 of Set 8 | daxian
# City not found. Skipping...
# Processing Record 3 of Set 8 | ekhabi
# Processing Record 4 of Set 8 | berlevag
# Processing Record 5 of Set 8 | tiznit
# Processing Record 6 of Set 8 | sur
# Processing Record 7 of Set 8 | kon tum
# Processing Record 8 of Set 8 | zemetchino
# Processing Record 9 of Set 8 | manono
# Processing Record 10 of Set 8 | gaziantep
# Processing Record 11 of Set 8 | norrkoping
# Processing Record 12 of Set 8 | pachino
# Processing Record 13 of Set 8 | tortosa
# Processing Record 14 of Set 8 | aswan
# Processing Record 15 of Set 8 | xinqing
# Processing Record 16 of Set 8 | fuxin
# Processing Record 17 of Set 8 | zhanaozen
# Processing Record 18 of Set 8 | ola
# Processing Record 19 of Set 8 | aravete
# Processing Record 20 of Set 8 | sharjah
# Processing Record 21 of Set 8 | west wendover
# Processing Record 22 of Set 8 | ulladulla
# Processing Record 23 of Set 8 | buraydah
# Processing Record 24 of Set 8 | kalengwa
# Processing Record 25 of Set 8 | labuhan
# Processing Record 26 of Set 8 | charters towers
# Processing Record 27 of Set 8 | homer
# Processing Record 28 of Set 8 | hof
# Processing Record 29 of Set 8 | bonthe
# Processing Record 30 of Set 8 | severo-kurilsk
# Processing Record 31 of Set 8 | tingo maria
# Processing Record 32 of Set 8 | abu samrah
# Processing Record 33 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 8 | isangel
# Processing Record 35 of Set 8 | sokolo
# Processing Record 36 of Set 8 | inta
# Processing Record 37 of Set 8 | sioux lookout
# Processing Record 38 of Set 8 | mezhova
# Processing Record 39 of Set 8 | adrar
# Processing Record 40 of Set 8 | edelira
# Processing Record 41 of Set 8 | prince rupert
# Processing Record 42 of Set 8 | hammerfest
# Processing Record 43 of Set 8 | okhotsk
# Processing Record 44 of Set 8 | geraldton
# Processing Record 45 of Set 8 | tessalit
# Processing Record 46 of Set 8 | trairi
# Processing Record 47 of Set 8 | palafrugell
# Processing Record 48 of Set 8 | jimenez
# Processing Record 49 of Set 8 | alofi
# Processing Record 50 of Set 8 | east london
# Processing Record 1 of Set 9 | torbat-e jam
# Processing Record 2 of Set 9 | pombia
# Processing Record 3 of Set 9 | lorengau
# Processing Record 4 of Set 9 | bahia blanca
# Processing Record 5 of Set 9 | panjwin
# City not found. Skipping...
# Processing Record 6 of Set 9 | aksu
# Processing Record 7 of Set 9 | bathsheba
# Processing Record 8 of Set 9 | zeya
# Processing Record 9 of Set 9 | sao filipe
# Processing Record 10 of Set 9 | coahuayana
# Processing Record 11 of Set 9 | bulgan
# Processing Record 12 of Set 9 | port-gentil
# Processing Record 13 of Set 9 | beyneu
# Processing Record 14 of Set 9 | gamba
# Processing Record 15 of Set 9 | mount isa
# Processing Record 16 of Set 9 | mehamn
# Processing Record 17 of Set 9 | kameshkovo
# Processing Record 18 of Set 9 | diego de almagro
# Processing Record 19 of Set 9 | maniitsoq
# Processing Record 20 of Set 9 | pimentel
# Processing Record 21 of Set 9 | grand gaube
# Processing Record 22 of Set 9 | sept-iles
# Processing Record 23 of Set 9 | shieli
# Processing Record 24 of Set 9 | palmer
# Processing Record 25 of Set 9 | khuzhir
# Processing Record 26 of Set 9 | manbij
# Processing Record 27 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 9 | ibra
# Processing Record 29 of Set 9 | inuvik
# Processing Record 30 of Set 9 | salisbury
# Processing Record 31 of Set 9 | roma
# Processing Record 32 of Set 9 | mahebourg
# Processing Record 33 of Set 9 | atherton
# Processing Record 34 of Set 9 | benjamin aceval
# Processing Record 35 of Set 9 | sabang
# Processing Record 36 of Set 9 | bara
# Processing Record 37 of Set 9 | bilibino
# Processing Record 38 of Set 9 | mbandaka
# Processing Record 39 of Set 9 | tiksi
# Processing Record 40 of Set 9 | tazovskiy
# Processing Record 41 of Set 9 | manggar
# Processing Record 42 of Set 9 | binzhou
# Processing Record 43 of Set 9 | general roca
# Processing Record 44 of Set 9 | libreville
# Processing Record 45 of Set 9 | muros
# Processing Record 46 of Set 9 | rabo de peixe
# Processing Record 47 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 9 | mahanoro
# Processing Record 49 of Set 9 | north bend
# Processing Record 50 of Set 9 | hurricane
# Processing Record 1 of Set 10 | cabedelo
# Processing Record 2 of Set 10 | csurgo
# Processing Record 3 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 4 of Set 10 | teya
# Processing Record 5 of Set 10 | mao
# Processing Record 6 of Set 10 | lampazos de naranjo
# Processing Record 7 of Set 10 | yithion
# City not found. Skipping...
# Processing Record 8 of Set 10 | ayan
# Processing Record 9 of Set 10 | banda aceh
# Processing Record 10 of Set 10 | saint-pierre
# Processing Record 11 of Set 10 | mogadishu
# Processing Record 12 of Set 10 | high rock
# Processing Record 13 of Set 10 | kaduqli
# Processing Record 14 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 15 of Set 10 | young
# Processing Record 16 of Set 10 | cockburn town
# Processing Record 17 of Set 10 | nicolas bravo
# Processing Record 18 of Set 10 | yulara
# Processing Record 19 of Set 10 | caravelas
# Processing Record 20 of Set 10 | matadi
# Processing Record 21 of Set 10 | pismo beach
# Processing Record 22 of Set 10 | aberystwyth
# Processing Record 23 of Set 10 | mwense
# Processing Record 24 of Set 10 | burnie
# Processing Record 25 of Set 10 | hambantota
# Processing Record 26 of Set 10 | byron bay
# Processing Record 27 of Set 10 | bereda
# Processing Record 28 of Set 10 | te anau
# Processing Record 29 of Set 10 | raudeberg
# Processing Record 30 of Set 10 | high level
# Processing Record 31 of Set 10 | bardiyah
# Processing Record 32 of Set 10 | hadrut
# Processing Record 33 of Set 10 | tuatapere
# Processing Record 34 of Set 10 | dubbo
# Processing Record 35 of Set 10 | belyy yar
# Processing Record 36 of Set 10 | kushiro
# Processing Record 37 of Set 10 | innisfail
# Processing Record 38 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 10 | ingham
# Processing Record 40 of Set 10 | taoudenni
# Processing Record 41 of Set 10 | balkanabat
# Processing Record 42 of Set 10 | valdivia
# Processing Record 43 of Set 10 | andevoranto
# City not found. Skipping...
# Processing Record 44 of Set 10 | deep river
# Processing Record 45 of Set 10 | anadyr
# Processing Record 46 of Set 10 | podor
# Processing Record 47 of Set 10 | sao fidelis
# Processing Record 48 of Set 10 | ballina
# Processing Record 49 of Set 10 | tucuman
# Processing Record 50 of Set 10 | sestri levante
# Processing Record 1 of Set 11 | aykhal
# Processing Record 2 of Set 11 | constitucion
# Processing Record 3 of Set 11 | mansa
# Processing Record 4 of Set 11 | hobyo
# Processing Record 5 of Set 11 | akdagmadeni
# Processing Record 6 of Set 11 | agadez
# Processing Record 7 of Set 11 | ilhabela
# Processing Record 8 of Set 11 | chapleau
# Processing Record 9 of Set 11 | southbridge
# Processing Record 10 of Set 11 | thinadhoo
# Processing Record 11 of Set 11 | villa carlos paz
# Processing Record 12 of Set 11 | khanewal
# Processing Record 13 of Set 11 | cherdyn
# Processing Record 14 of Set 11 | marsh harbour
# Processing Record 15 of Set 11 | ucluelet
# Processing Record 16 of Set 11 | polyarnyy
# Processing Record 17 of Set 11 | monrovia
# Processing Record 18 of Set 11 | muisne
# Processing Record 19 of Set 11 | lerwick
# Processing Record 20 of Set 11 | araxa
# Processing Record 21 of Set 11 | kattivakkam
# Processing Record 22 of Set 11 | athens
# Processing Record 23 of Set 11 | mwinilunga
# Processing Record 24 of Set 11 | jacareacanga
# Processing Record 25 of Set 11 | falun
# Processing Record 26 of Set 11 | sao felix do xingu
# Processing Record 27 of Set 11 | soresina
# Processing Record 28 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 11 | nyazepetrovsk
# Processing Record 30 of Set 11 | nadvoitsy
# Processing Record 31 of Set 11 | gander
# Processing Record 32 of Set 11 | challakere
# Processing Record 33 of Set 11 | saint-paul
# Processing Record 34 of Set 11 | cosala
# Processing Record 35 of Set 11 | clyde river
# Processing Record 36 of Set 11 | san pedro carcha
# Processing Record 37 of Set 11 | sri aman
# Processing Record 38 of Set 11 | abu jubayhah
# City not found. Skipping...
# Processing Record 39 of Set 11 | kaeo
# Processing Record 40 of Set 11 | quatre cocos
# Processing Record 41 of Set 11 | ambulu
# Processing Record 42 of Set 11 | karratha
# Processing Record 43 of Set 11 | mastic beach
# Processing Record 44 of Set 11 | votkinsk
# Processing Record 45 of Set 11 | las cruces
# Processing Record 46 of Set 11 | kidal
# Processing Record 47 of Set 11 | viedma
# Processing Record 48 of Set 11 | mulhouse
# Processing Record 49 of Set 11 | broken hill
# Processing Record 50 of Set 11 | effingham
# Processing Record 1 of Set 12 | metro
# Processing Record 2 of Set 12 | sechura
# Processing Record 3 of Set 12 | nang rong
# Processing Record 4 of Set 12 | huilong
# Processing Record 5 of Set 12 | acapulco

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
